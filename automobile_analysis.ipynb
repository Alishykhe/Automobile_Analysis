# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('automobile_data.csv')
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df1 = df.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             58 non-null     int64
#  1   company           58 non-null     object
#  2   body-style        58 non-null     object
#  3   wheel-base        58 non-null     float64
#  4   length            58 non-null     float64
#  5   engine-type       58 non-null     object
#  6   num-of-cylinders  58 non-null     object
#  7   horsepower        58 non-null     int64
#  8   average-mileage   58 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.0+ KB

# %%
df1 = df.fillna('Unknown')

# %%
df1['price'] = df['price'].fillna(df['price'].mean())

# %%
df1['price']
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df1.rename(columns={'body-style' : 'Style', 'wheel-base' : 'Wheel' , 'engine-type' : 'engine' , 'num-of-cylinders' : 'cylinders', 
                   'average-mileage' : 'Mileage' }, inplace= True)
df1
# Out:
#     index      company        Style  Wheel  length engine cylinders  \
# 0       0  alfa-romero  convertible   88.6   168.8   dohc      four
# 1       1  alfa-romero  convertible   88.6   168.8   dohc      four
# 2       2  alfa-romero    hatchback   94.5   171.2   ohcv       six
# 3       3         audi        sedan   99.8   176.6    ohc      four
# 4       4         audi        sedan   99.4   176.6    ohc      five
# ..    ...          ...          ...    ...     ...    ...       ...
# 56     81   volkswagen        sedan   97.3   171.7    ohc      four
# 57     82   volkswagen        sedan   97.3   171.7    ohc      four
# 58     86   volkswagen        sedan   97.3   171.7    ohc      four
# 59     87        volvo        sedan  104.3   188.8    ohc      four
# 60     88        volvo        wagon  104.3   188.8    ohc      four
#
#     horsepower  Mileage    price
# 0          111       21  13495.0
# 1          111       21  16500.0
# 2          154       19  16500.0
# ...

# %%
df1.isnull().sum()
# Out:
# index         0
# company       0
# Style         0
# Wheel         0
# length        0
# engine        0
# cylinders     0
# horsepower    0
# Mileage       0
# price         0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['index', 'company', 'Style', 'Wheel', 'length', 'engine', 'cylinders',
#        'horsepower', 'Mileage', 'price'],
#       dtype='object')

# %%
horse_power_comparison = df1.groupby('engine')['price'].mean().reset_index()
horse_power_comparison
# Out:
#   engine         price
# 0   dohc  22709.000000
# 1  dohcv  15387.000000
# 2      l   5151.000000
# 3    ohc  12375.304348
# 4   ohcf  35528.000000
# 5   ohcv  30471.800000
# 6  rotor  11845.000000

# %%
df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Length: 61, dtype: bool

# %%
df1.columns
# Out:
# Index(['index', 'company', 'Style', 'Wheel', 'length', 'engine', 'cylinders',
#        'horsepower', 'Mileage', 'price'],
#       dtype='object')

# %% [markdown]
# EDA ANALYSIS

# %%
com = sns.countplot(data= df1, x = 'company')
sns.countplot(rc={'figure.figsize':(15,5)})
plt.xticks(rotation=90)
for bars in com.containers:
    com.bar_label(bars)

# %%
plt.figure(figsize= (12,6))
sns.boxplot(data= df1, x= 'company', y= 'price' , palette = 'coolwarm', hue= 'company')
plt.xticks(rotation=90)
plt.title('Price Trends Across Car Brands')
plt.show()

# %% [markdown]
# Luxury brands like BMW, Mercedes-Benz, and Porsche have the highest price variations, while budget brands like Chevrolet, Dodge, and Nissan show consistent pricing. Outliers in Mercedes and Porsche indicate ultra-luxury models.

# %%
grouped = df1.groupby('engine')['price'].mean()
sns.barplot( data= df1, x = 'engine' , y= 'price', hue = 'company')
plt.xlabel('Engine type')
plt.ylabel('Average price')
plt.title('Average price by engine type')
# Out:
# Text(0.5, 1.0, 'Average price by engine type')

# %%
sns.scatterplot(x= 'Mileage', y= 'engine', data = df1, hue = 'company')
# Out:
# <Axes: xlabel='Mileage', ylabel='engine'>

# %% [markdown]
# Different car brands use a variety of engine types but OHC engines are the most common across different mileage levels. DOHC engines tend to be in lower-mileage cars, while rotor engines are quite rare showing they are used in specific cases.

# %%
sns.countplot(data = df1, x= 'Style', palette = 'Set2', hue = 'Style', legend = False)
plt.title("Most Popular Car Styles in the Market")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The sedan is the most popular car style in the market, followed by hatchbacks while convertibles and hardtops are the least common.

# %% [markdown]
# CONCLUSION:
#
# This analysis highlights that most fuel-efficient cars have OHC engines, while DOHC engines offer a mix of mileage and performance. Additionally, sedans dominate the market, proving that buyers prioritize comfort and practicality over specialized styles.
